# %% [markdown]
# ### 용어
# context: question에 대한 hint sentence의 묶음 <br>
# sentence: context를 이루고 있는 문장 하나 <br>
# question: 질문 (문장 하나)

# %%
import itertools
import numpy as np
import os
import pickle

from datetime import datetime
import tensorflow as tf
from tensorflow.contrib.layers import batch_norm
from tensorflow.contrib.layers import fully_connected
from tensorflow.contrib import rnn
from tensorflow.contrib import slim
from time import time
from tqdm import tqdm

# %%
# question, answer, context, label
with open('./babi_preprocessd/train_dataset_masked.pkl', 'rb') as f:
    train = pickle.load(f)
with open('./babi_preprocessd/val_dataset_masked.pkl', 'rb') as f:
    val = pickle.load(f)
with open('./babi_preprocessd/test_dataset_masked.pkl', 'rb') as f:
    test = pickle.load(f)

# %%
with open('./babi_preprocessd/c_word_set.pkl', 'rb') as f:
    c_word_set = pickle.load(f)
with open('./babi_preprocessd/q_word_set.pkl', 'rb') as f:
    q_word_set = pickle.load(f)
with open('./babi_preprocessd/a_word_set.pkl', 'rb') as f:
    a_word_set = pickle.load(f)
with open('./babi_preprocessd/cqa_word_set.pkl', 'rb') as f:
    cqa_word_set = pickle.load(f)

# %%
[train_q, train_a, train_c, train_l, train_c_real_len, train_q_real_len] = train
[val_q, val_a, val_c, val_l, val_c_real_len, val_q_real_len] = val
[test_q, test_a, test_c, test_l, test_c_real_len, test_q_real_len] = test

# %%
c_max_len = 20
s_max_len = 12
q_max_len = 12
mask_index = 0

# %%
# parameters
learning_rate = 2e-4
batch_size = 64
iter_time = 6
display_step = 100
seed = 9

# %% [markdown]
# * context words: 124 <br>
# * question words: 88 <br>
# * answer words: 41 <br>
# * all words: 159 <br>
# * s,q max len: 12 <br>
# * c max len: 20

# %% [markdown]
# #### LSTM for context
# * 32 unit LSTM

# %% [markdown]
# #### LSTM for question
# * 32 unit LSTM

# %%
# model parameter
s_input_step = s_max_len
s_hidden = 32
# ---
q_input_step = q_max_len
q_hidden = 32

# %%
# embed matrix
c_word_embed = 32
c_vocab_size = len(c_word_set)+1 # consider masking
c_word_embed_matrix = tf.Variable(tf.random_uniform(shape=[c_vocab_size, c_word_embed], minval=-1, maxval=1, seed= seed))
# ---
q_word_embed = 32
q_vocab_size = len(q_word_set)+1 # consider masking
q_word_embed_matrix = tf.Variable(tf.random_uniform(shape=[q_vocab_size, q_word_embed], minval=-1, maxval=1, seed=seed))

# %%
# input, output
c = tf.placeholder(dtype=tf.int32, shape=[batch_size, c_max_len, s_max_len])
c_real_len = tf.placeholder(dtype=tf.int32, shape=[batch_size, c_max_len])
s = tf.placeholder(dtype=tf.int32, shape=[batch_size, s_max_len]) 
q = tf.placeholder(dtype=tf.int32, shape=[batch_size, q_max_len])
q_real_len = tf.placeholder(dtype=tf.int32, shape=[batch_size])
l = tf.placeholder(dtype=tf.float32, shape=[batch_size, c_max_len, c_max_len])
a = tf.placeholder(dtype=tf.float32, shape=[batch_size, len(cqa_word_set)])
training_phase = tf.placeholder(dtype=tf.bool)

# %%
def contextLSTM(c, l, c_real_len, reuse=True, scope= "contextLSTM"):
    
    def sentenceLSTM(s, s_real_len, s_hidden=s_hidden, s_max_len= s_max_len, reuse=reuse, scope= "sentenceLSTM"):
        """
        embedding sentence

        Arguments
            s: sentence (word index list), shape = [batch_size, 12]
            s_real_len: length of the sentence before zero padding, int32

        Returns
            embedded_s: embedded sentence, shape = [batch_size, 32]
        """
        embedded_sent_word = tf.nn.embedding_lookup(c_word_embed_matrix, s)
        s_input = tf.unstack(embedded_sent_word, num=s_max_len, axis=1)
        lstm_cell = rnn.BasicLSTMCell(s_hidden, reuse=reuse)
        outputs, _ = rnn.static_rnn(lstm_cell, s_input, dtype=tf.float32, scope= scope)
        # 'outputs' is a list of output at every timestep, we pack them in a Tensor
        outputs = tf.stack(outputs)
        # and change back dimension to [batch_size(64), s_max_len(12), s_hidden(32)]
        outputs = tf.transpose(outputs, [1, 0, 2])
        # Start indices for each sample
        index = tf.range(0, batch_size) * (s_max_len) + (s_real_len-1)
        # Indexing
        outputs = tf.gather(tf.reshape(outputs, [-1, s_hidden]), index)
        return outputs
    
    """
    Args
        c: list of sentences, shape = [batch_size, 20, 12]
        l: list of labels, shape = [batch_size, 20, 20]
        c_real_len: list of real length, shape = [batch_size, 20]
        
    Returns
        tagged_c_objects: list of embedded sentence + label, shape = [batch_size, 52] 20개
        len(tagged_c_objects) = 20
    """
    context = tf.unstack(c, axis=1) 
    real_lens = tf.unstack(c_real_len, axis=1)
    labels = tf.unstack(l, axis=1)
    tagged_c_objects = []
    for sentence, real_len, label in zip(context, real_lens, labels):
        s_embedded = sentenceLSTM(sentence, real_len, reuse=reuse)
        c_embedded = tf.concat([s_embedded, label], axis= 1)
        tagged_c_objects.append(c_embedded)
                                 
    return tagged_c_objects

# %%
def questionLSTM(q, q_real_len, q_hidden=q_hidden, reuse=True, scope = "questionLSTM"):
    """
    Args
        q: zero padded qeustions, shape=[batch_size, q_max_len]
        q_real_len: original question length, shape = [batch_size, 1]
        
    Returns
        embedded_q: embedded questions, shape = [batch_size, q_hidden(32)]
    """
    embedded_q_word = tf.nn.embedding_lookup(q_word_embed_matrix, q)
    q_input = tf.unstack(embedded_q_word, num=q_max_len, axis=1)
    lstm_cell = rnn.BasicLSTMCell(q_hidden, reuse=reuse)
    outputs, _ = rnn.static_rnn(lstm_cell, q_input, dtype=tf.float32, scope = scope)
    # 'outputs' is a list of output at every timestep, we pack them in a Tensor
    outputs = tf.stack(outputs)
    # and change back dimension to [batch_size(64), q_max_len(12), s_hidden(32)]
    outputs = tf.transpose(outputs, [1, 0, 2])
    # Start indices for each sample
    index = tf.range(0, batch_size) * (q_max_len) + (q_real_len-1)
    # Indexing
    outputs = tf.gather(tf.reshape(outputs, [-1, s_hidden]), index)
    return outputs

# %%
def convert_to_RN_input(embedded_c, embedded_q):
    """
    
    Args
        embedded_c: output of contextLSTM, 20 length list of embedded sentences
        embedded_q: output of questionLSTM, embedded question
        
    Returns
        RN_input: input for RN g_theta, shape = [batch_size*190, (52+52+32)]
        considered batch_size and all combinations
    """
    # 20 combination 2 --> total 190 object pairs
    object_pairs = list(itertools.combinations(embedded_c, 2))
    # concatenate with question
    RN_inputs = []
    for object_pair in object_pairs:
        RN_input = tf.concat([object_pair[0], object_pair[1], embedded_q], axis=1)
        RN_inputs.append(RN_input)
    
    return tf.concat(RN_inputs, axis=0)

# %% [markdown]
# #### RN
# * $g_\theta$: 4 layer, all 256 units MLP, ReLU
# * $f_\phi$: 3 layer, 256/512/159 units MLP, ReLU, sotmax

# %%
g_units = [256,256,256,256]
f_units = [256,512,159]

# %%
def fc(inputs, output_shape, activation_fcn = tf.nn.relu, name="fc"):
    output = slim.fully_connected(inputs, int(output_shape), activation_fn=activation_fcn)
    return output

# %%
def batch_norm_relu(inputs, output_shape, phase=True, scope=None, activation= True):
    with tf.variable_scope(scope):
        h1 = fully_connected(inputs, output_shape, activation_fn=None, scope='dense')
        h2 = batch_norm(h1, decay = 0.95 ,center=True, scale=True, 
                        is_training=phase, scope='bn', updates_collections= None)
        if activation:
            o = tf.nn.relu(h2, 'relu')
        else:
            o = h2
        return o

# %%
def g_theta(RN_input, scope= 'g_theta', reuse= True, phase=True): 
    """
    Args
        RN_input: [o_i, o_j, q], shape = [batch_size*190, 136]
        
    Returns
        g_output: shape = [190, batch_size, 256]
    """
    input_dim = RN_input.shape[1]
    with tf.variable_scope(scope, reuse= reuse) as scope:
        # if not reuse: log.warn(scope.name): reuse하는지 확인하기 위한 출력옵션
#         if not reuse:
#             print(scope.name)
        g_1 = batch_norm_relu(RN_input, g_units[0], scope= "g_1", phase=phase)
        g_2 = batch_norm_relu(g_1, g_units[1], scope= "g_2", phase=phase)
        g_3 = batch_norm_relu(g_2, g_units[2], scope= "g_3", phase=phase)
        g_4 = batch_norm_relu(g_3, g_units[3], scope= "g_4", phase=phase)
    g_output = tf.reshape(g_4, shape=[190, batch_size, g_units[3]])
    return g_output

# %%
def f_phi(g, scope= 'f_phi', reuse=True, phase=True):
    """
    Args
        g: g_theta result, shape = [190, batch_size, 256]
        
    Returns
        f_output: shape = [batch_size, 159]
    """
    f_input = tf.reduce_sum(g, axis=0)
    with tf.variable_scope(scope, reuse=reuse) as scope:
        f_1 = batch_norm_relu(f_input, f_units[0], scope= "f_1", phase=phase)
        f_2 = batch_norm_relu(f_1, f_units[1], scope= "f_2", phase=phase)
        f_3 = batch_norm_relu(f_2, f_units[2], activation= None, scope= "f_3", phase=phase)
    return f_3

# %% [markdown]
# reuse...

# %%
def model(c, q, l, c_real_len, q_real_len, phase=True):
    embedded_c = contextLSTM(c, l, c_real_len, reuse=True)
    embedded_q = questionLSTM(q, q_real_len, reuse=None)
    RN_input = convert_to_RN_input(embedded_c, embedded_q)
    f_input = g_theta(RN_input, reuse=None, phase=phase)
    prediction = f_phi(f_input, reuse=None, phase=phase)
    return prediction

# %%
prediction = model(c,q,l,c_real_len, q_real_len, training_phase)

# %%
tf.trainable_variables()
# Out:
# [<tf.Variable 'Variable:0' shape=(125, 32) dtype=float32_ref>,
#  <tf.Variable 'Variable_1:0' shape=(89, 32) dtype=float32_ref>,
#  <tf.Variable 'sentenceLSTM/basic_lstm_cell/weights:0' shape=(64, 128) dtype=float32_ref>,
#  <tf.Variable 'sentenceLSTM/basic_lstm_cell/biases:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'questionLSTM/basic_lstm_cell/weights:0' shape=(64, 128) dtype=float32_ref>,
#  <tf.Variable 'questionLSTM/basic_lstm_cell/biases:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'g_theta/g_1/dense/weights:0' shape=(136, 256) dtype=float32_ref>,
#  <tf.Variable 'g_theta/g_1/dense/biases:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'g_theta/g_1/bn/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'g_theta/g_1/bn/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'g_theta/g_2/dense/weights:0' shape=(256, 256) dtype=float32_ref>,
#  <tf.Variable 'g_theta/g_2/dense/biases:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'g_theta/g_2/bn/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'g_theta/g_2/bn/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'g_theta/g_3/dense/weights:0' shape=(256, 256) dtype=float32_ref>,
#  <tf.Variable 'g_theta/g_3/dense/biases:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'g_theta/g_3/bn/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'g_theta/g_3/bn/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'g_theta/g_4/dense/weights:0' shape=(256, 256) dtype=float32_ref>,
#  <tf.Variable 'g_theta/g_4/dense/biases:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'g_theta/g_4/bn/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'g_theta/g_4/bn/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'f_phi/f_1/dense/weights:0' shape=(256, 256) dtype=float32_ref>,
#  <tf.Variable 'f_phi/f_1/dense/biases:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'f_phi/f_1/bn/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'f_phi/f_1/bn/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'f_phi/f_2/dense/weights:0' shape=(256, 512) dtype=float32_ref>,
#  <tf.Variable 'f_phi/f_2/dense/biases:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'f_phi/f_2/bn/beta:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'f_phi/f_2/bn/gamma:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'f_phi/f_3/dense/weights:0' shape=(512, 159) dtype=float32_ref>,
#  <tf.Variable 'f_phi/f_3/dense/biases:0' shape=(159,) dtype=float32_ref>,
#  <tf.Variable 'f_phi/f_3/bn/beta:0' shape=(159,) dtype=float32_ref>,
#  <tf.Variable 'f_phi/f_3/bn/gamma:0' shape=(159,) dtype=float32_ref>]

# %% [markdown]
# #### Optimization
# * 64 mini batches
# * cross-entropy loss function
# * Adam optimizer
# * learning rate: 2e-4

# %% [markdown]
# ## Issues
# 1. multiple answer?

# %%
correct = tf.equal(tf.argmax(prediction, axis=1), tf.argmax(a, axis=1))
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
accuracy_train = tf.summary.scalar("accuracy_train", accuracy)

# %%
loss = tf.nn.softmax_cross_entropy_with_logits(logits=prediction, labels=a)

# %%
loss_train = tf.summaryary.scalar("loss_train", loss)

# %%
global_step = tf.Variable(0, name="global_step", trainable=False)

# %%
opt = tf.train.AdamOptimizer(learning_rate=learning_rate)
optimizer = opt.minimize(loss, global_step=global_step)

# %% [markdown]
# ## Train!

# %%
def batch_iter(c, q, l, a, c_real_len, q_real_len, batch_size=batch_size, num_epochs=iter_time, shuffle=True):
    """
    Generates a batch iterator for a dataset.
    """
    c = np.array(c)
    q = np.array(q)
    l = np.array(l)
    a = np.array(a)
    c_real_len = np.array(c_real_len)
    q_real_len = np.array(q_real_len)
    data_size = len(q)
    num_batches_per_epoch = int(data_size/batch_size) + 1
    for epoch in range(num_epochs):
        print("In epoch >> " + str(epoch + 1))
        print("num batches per epoch is: " + str(num_batches_per_epoch))
        # Shuffle the data at each epoch
        if shuffle:
            shuffle_indices = np.random.permutation(np.arange(data_size))
            c_shuffled = c[shuffle_indices]
            q_shuffled = q[shuffle_indices]
            l_shuffled = l[shuffle_indices]
            a_shuffled = a[shuffle_indices]
            c_real_len_shuffled = c_real_len[shuffle_indices]
            q_real_len_shuffled = q_real_len[shuffle_indices]
        else:
            c_shuffled = c
            q_shuffled = q
            l_shuffled = l
            a_shuffled = a
            c_real_len_shuffled = c_real_len
            q_real_len_shuffled = q_real_len
        
        for batch_num in range(num_batches_per_epoch):
            start_index = batch_num * batch_size
            end_index = (batch_num + 1) * batch_size
            if end_index < data_size:
                c_batch, q_batch, l_batch, a_batch, c_real_len_batch, q_real_len_batch = c_shuffled[start_index:end_index], q_shuffled[start_index:end_index], l_shuffled[start_index:end_index], a_shuffled[start_index:end_index], c_real_len_shuffled[start_index:end_index], q_real_len_shuffled[start_index:end_index]
            yield list(zip(c_batch, q_batch, l_batch, a_batch, c_real_len_batch, q_real_len_batch))

# %%
date = datetime.fromtimestamp(time()).strftime('%Y-%m-%d_%H:%M:%S')
model_id = 'RN' + date
save_dir = './babi_result/lookup_table/%s' %(model_id)
save_summary_path = os.path.join(save_dir, 'model_summary')
save_variable_path = os.path.join(save_dir, 'model_variables')

# %%
if not os.path.exists(save_dir):
    os.makedirs(save_dir)
    os.makedirs(save_summary_path)
    os.makedirs(save_variable_path)

# %%
merged = tf.summary.merge_all(key='summaries')

# %%
loss_val = tf.scalar.summary('loss_val', loss)
acc_val = tf.scalar.summary('acc_val', accuracy)

# %%
start_time = time()
with tf.Session() as sess:
    init = tf.global_variables_initializer()
    sess.run(init)
    saver = tf.train.Saver(max_to_keep=4)
    summary_writer = tf.summary.FileWriter(save_summary_path, sess.graph)    
    print("====training====")   
    batch_train = batch_iter(train_c, train_q, train_l, train_a, train_c_real_len, train_q_real_len)
    for train in batch_train:
        c_batch, q_batch, l_batch, a_batch, c_real_len_batch, q_real_len_batch = zip(*train)

#         current_step = sess.run(global_step, feed_dict={c:c_batch, q:q_batch, l:l_batch, a:a_batch, c_real_len:c_real_len_batch, q_real_len:q_real_len_batch, training_phase : True})
#         optimizer.run(feed_dict={c:c_batch, q:q_batch, l:l_batch, a:a_batch, c_real_len:c_real_len_batch, q_real_len:q_real_len_batch, training_phase : True})
#         train_summaries = sess.run(merged, feed_dict={c:c_batch, q:q_batch, l:l_batch, a:a_batch, c_real_len:c_real_len_batch, q_real_len:q_real_len_batch, training_phase : True})

        feed_dict={c:c_batch, q:q_batch, l:l_batch, a:a_batch, c_real_len:c_real_len_batch, q_real_len:q_real_len_batch,training_phase : True }
        current_step, _ , train_summaries = sess.run([global_step, optimizer, merged], feed_dict)

        summary_writer.add_summary(train_summaries, current_step)
        if current_step % (display_step) == 0:
            print("step: {}".format(current_step))
            print("====validation start====")
            batch_val = batch_iter(val_c, val_q, val_l, val_a, val_c_real_len, val_q_real_len, num_epochs=1)
            accs = []
            for val in batch_val:
                c_val, q_val, l_val, a_val, c_real_len_val, q_real_len_val = zip(*val)

#                 acc = accuracy.eval(feed_dict={c:c_val, q:q_val, l:l_val, a:a_val, c_real_len:c_real_len_val, q_real_len:q_real_len_val, training_phase : False})
#                 accs.append(acc)
#                 val_summary_loss = sess.run(loss_val, feed_dict={c:c_val, q:q_val, l:l_val, a:a_val, c_real_len:c_real_len_val, q_real_len:q_real_len_val, training_phase : False})
#                 val_summary_acc = sess.run(acc_val, feed_dict={c:c_val, q:q_val, l:l_val, a:a_val, c_real_len:c_real_len_val, q_real_len:q_real_len_val, training_phase : False})

                feed_dict={c:c_val, q:q_val, l:l_val, a:a_val, c_real_len:c_real_len_val, q_real_len:q_real_len_val,training_phase : False}
                acc, val_summary_loss, val_summary_acc = sess.run([accuracy, loss_val, acc_val] , feed_dict)
                accs.append(acc)
                
                summary_writer.add_summary(val_summary_loss, current_step)
                summary-writer.add_summary(val_summary_acc, current_step)
            print("Mean accuracy=" + str(sum(accs)/len(accs)))
            saver.save(sess, save_path = save_summary_path, global_step=current_step)
            print("====training====")
end_time = time()
# Out:
# ====training====
# In epoch >> 1
# num batches per epoch is: 2812
# step: 0
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0100410657051
# ====training====
# step: 100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.308476896368
# ====training====
# step: 200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.405991252671
# ====training====
# step: 300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.465494791667
# ====training====
# step: 400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.479609041132
# ====training====
# step: 500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.495651375534
# ====training====
# step: 600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.50636852297
# ====training====
# step: 700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.505517160791
# ====training====
# step: 800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.526667668269
# ====training====
# step: 900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.528979700855
# ====training====
# step: 1000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.542392828526
# ====training====
# step: 1100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.547367454594
# ====training====
# step: 1200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.551933092949
# ====training====
# step: 1300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.557800814637
# ====training====
# step: 1400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.561748798077
# ====training====
# step: 1500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.563810430021
# ====training====
# step: 1600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.568459535256
# ====training====
# step: 1700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.578425480769
# ====training====
# step: 1800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.579719217415
# ====training====
# step: 1900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.58848323985
# ====training====
# step: 2000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.589902176816
# ====training====
# step: 2100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.595344217415
# ====training====
# step: 2200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.597172142094
# ====training====
# step: 2300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.607263287927
# ====training====
# step: 2400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.606328458868
# ====training====
# step: 2500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.60593616453
# ====training====
# step: 2600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.608047876603
# ====training====
# step: 2700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.61582698985
# ====training====
# step: 2800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.618022168803
# ====training====
# In epoch >> 2
# num batches per epoch is: 2812
# step: 2900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.620743189103
# ====training====
# step: 3000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.624691172543
# ====training====
# step: 3100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.625125200321
# ====training====
# step: 3200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.624549278846
# ====training====
# step: 3300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.628513955662
# ====training====
# step: 3400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.632670606303
# ====training====
# step: 3500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.632553752671
# ====training====
# step: 3600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.633246527778
# ====training====
# step: 3700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.634565304487
# ====training====
# step: 3800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.636176215278
# ====training====
# step: 3900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.636443309295
# ====training====
# step: 4000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.634223090278
# ====training====
# step: 4100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.63620960203
# ====training====
# step: 4200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.640090811966
# ====training====
# step: 4300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.640892094017
# ====training====
# step: 4400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.642094017094
# ====training====
# step: 4500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.644172342415
# ====training====
# step: 4600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.64491519765
# ====training====
# step: 4700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.648921607906
# ====training====
# step: 4800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.649439102564
# ====training====
# step: 4900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.65195980235
# ====training====
# step: 5000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.653495592949
# ====training====
# step: 5100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.659321581197
# ====training====
# step: 5200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.660223023504
# ====training====
# step: 5300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.659555288462
# ====training====
# step: 5400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.664396367521
# ====training====
# step: 5500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.665498130342
# ====training====
# step: 5600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.672100360577
# ====training====
# In epoch >> 3
# num batches per epoch is: 2812
# step: 5700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.671424278846
# ====training====
# step: 5800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.672976762821
# ====training====
# step: 5900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.677208533654
# ====training====
# step: 6000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.680906116453
# ====training====
# step: 6100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.676156850962
# ====training====
# step: 6200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.682675614316
# ====training====
# step: 6300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.686222956731
# ====training====
# step: 6400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.689169337607
# ====training====
# step: 6500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.684495192308
# ====training====
# step: 6600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.688835470085
# ====training====
# step: 6700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.694661458333
# ====training====
# step: 6800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.696430956197
# ====training====
# step: 6900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.698601095085
# ====training====
# step: 7000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.697699652778
# ====training====
# step: 7100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.701572516026
# ====training====
# step: 7200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.70401809562
# ====training====
# step: 7300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.708375066774
# ====training====
# step: 7400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.708650507479
# ====training====
# step: 7500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.706622262286
# ====training====
# step: 7600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.710461738782
# ====training====
# step: 7700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.711263020833
# ====training====
# step: 7800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.71148838141
# ====training====
# step: 7900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.713449853098
# ====training====
# step: 8000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.71628772703
# ====training====
# step: 8100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.717172475962
# ====training====
# step: 8200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.717906984509
# ====training====
# step: 8300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.724317240919
# ====training====
# step: 8400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.724793002137
# ====training====
# In epoch >> 4
# num batches per epoch is: 2812
# step: 8500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.722180488782
# ====training====
# step: 8600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.725318843483
# ====training====
# step: 8700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.732555422009
# ====training====
# step: 8800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.727914663462
# ====training====
# step: 8900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.732872596154
# ====training====
# step: 9000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.732062967415
# ====training====
# step: 9100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.734483506944
# ====training====
# step: 9200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.734592013889
# ====training====
# step: 9300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.734742254274
# ====training====
# step: 9400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.73773036859
# ====training====
# step: 9500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.740877069979
# ====training====
# step: 9600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.738765357906
# ====training====
# step: 9700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.741102430556
# ====training====
# step: 9800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.739867120726
# ====training====
# step: 9900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.746694711538
# ====training====
# step: 10000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.745509481838
# ====training====
# step: 10100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.747704660791
# ====training====
# step: 10200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.747445913462
# ====training====
# step: 10300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.746694711538
# ====training====
# step: 10400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.74800514156
# ====training====
# step: 10500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.749190371261
# ====training====
# step: 10600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.74851428953
# ====training====
# step: 10700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.750217013889
# ====training====
# step: 10800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.754356971154
# ====training====
# step: 10900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.754532251603
# ====training====
# step: 11000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.75437366453
# ====training====
# step: 11100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.75398971688
# ====training====
# step: 11200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.75687767094
# ====training====
# In epoch >> 5
# num batches per epoch is: 2812
# step: 11300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.757503672543
# ====training====
# step: 11400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.761384882479
# ====training====
# step: 11500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.758371728098
# ====training====
# step: 11600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.757620526175
# ====training====
# step: 11700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.759022769765
# ====training====
# step: 11800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.762520032051
# ====training====
# step: 11900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.758880876068
# ====training====
# step: 12000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.758163060897
# ====training====
# step: 12100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.760942508013
# ====training====
# step: 12200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.762194511218
# ====training====
# step: 12300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.762728699252
# ====training====
# step: 12400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.761877337073
# ====training====
# step: 12500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.763137686966
# ====training====
# step: 12600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.76469017094
# ====training====
# step: 12700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.764130942842
# ====training====
# step: 12800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.765057425214
# ====training====
# step: 12900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.768212473291
# ====training====
# step: 13000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.76766159188
# ====training====
# step: 13100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.767953725962
# ====training====
# step: 13200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.768763354701
# ====training====
# step: 13300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.767953725962
# ====training====
# step: 13400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.768921941774
# ====training====
# step: 13500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.771334134615
# ====training====
# step: 13600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.770966880342
# ====training====
# step: 13700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.771492721688
# ====training====
# step: 13800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.773153712607
# ====training====
# step: 13900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.777585803953
# ====training====
# step: 14000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.776709401709
# ====training====
# In epoch >> 6
# num batches per epoch is: 2812
# step: 14100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.779405381944
# ====training====
# step: 14200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.778620793269
# ====training====
# step: 14300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.777577457265
# ====training====
# step: 14400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.782176482372
# ====training====
# step: 14500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.780498798077
# ====training====
# step: 14600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.77933860844
# ====training====
# step: 14700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.779522235577
# ====training====
# step: 14800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.782510349893
# ====training====
# step: 14900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.77968082265
# ====training====
# step: 15000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.780156583868
# ====training====
# step: 15100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.785874065171
# ====training====
# step: 15200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.780924479167
# ====training====
# step: 15300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.782702323718
# ====training====
# step: 15400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.784413394765
# ====training====
# step: 15500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.782076322115
# ====training====
# step: 15600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.784380008013
# ====training====
# step: 15700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.784254807692
# ====training====
# step: 15800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.78672542735
# ====training====
# step: 15900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.783562032585
# ====training====
# step: 16000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.786800547543
# ====training====
# step: 16100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.786625267094
# ====training====
# step: 16200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.783779046474
# ====training====
# step: 16300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.787226228632
# ====training====
# step: 16400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.785473424145
# ====training====
# step: 16500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.784864115919
# ====training====
# step: 16600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.784613715278
# ====training====
# step: 16700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.787409855769
# ====training====
# step: 16800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.786917401175
# ====training====

# %% [markdown]
# ### Save model variables

# %%
fname = os.path.join(save_variable_path, 'model_variables.txt')
with open(fname, 'w') as f:
    print('seed: {}'.format(seed), file=f)
    print('learning rate: {}'.format(learning_rate), file=f)
    print('batch_size: {}'.format(batch_size), file=f)
    print('epoch: {}'.format(iter_time), file=f)
    print('activation_fcn: relu', file = f)
    print('iteration_time: {}'.format(end_time-start_time), file=f)
