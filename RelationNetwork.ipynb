# %% [markdown]
# ### 용어
# context: question에 대한 hint sentence의 묶음 <br>
# sentence: context를 이루고 있는 문장 하나 <br>
# question: 질문 (문장 하나)

# %%
import itertools
import numpy as np
import pickle

import tensorflow as tf
from tensorflow.contrib import rnn
from tensorflow.contrib import slim
from tqdm import tqdm

# %%
# question, answer, context, label
with open('./babi_preprocessd/train_dataset_masked.pkl', 'rb') as f:
    train = pickle.load(f)
with open('./babi_preprocessd/val_dataset_masked.pkl', 'rb') as f:
    val = pickle.load(f)
with open('./babi_preprocessd/test_dataset_masked.pkl', 'rb') as f:
    test = pickle.load(f)

# %%
with open('./babi_preprocessd/c_word_set.pkl', 'rb') as f:
    c_word_set = pickle.load(f)
with open('./babi_preprocessd/q_word_set.pkl', 'rb') as f:
    q_word_set = pickle.load(f)
with open('./babi_preprocessd/a_word_set.pkl', 'rb') as f:
    a_word_set = pickle.load(f)
with open('./babi_preprocessd/cqa_word_set.pkl', 'rb') as f:
    cqa_word_set = pickle.load(f)

# %%
[train_q, train_a, train_c, train_l, train_c_real_len, train_q_real_len] = train
[val_q, val_a, val_c, val_l, val_c_real_len, val_q_real_len] = val
[test_q, test_a, test_c, test_l, test_c_real_len, test_q_real_len] = test

# %%
c_max_len = 20
s_max_len = 12
q_max_len = 12
mask_index = 0

# %%
# parameters
learning_rate = 2e-4
batch_size = 64
iter_time = 6
display_step = 100
seed = 9

# %% [markdown]
# * context words: 124 <br>
# * question words: 88 <br>
# * answer words: 41 <br>
# * all words: 159 <br>
# * s,q max len: 12 <br>
# * c max len: 20

# %% [markdown]
# #### LSTM for context
# * 32 unit LSTM

# %% [markdown]
# #### LSTM for question
# * 32 unit LSTM

# %%
# model parameter
s_input_step = s_max_len
s_hidden = 32
# ---
q_input_step = q_max_len
q_hidden = 32

# %%
# embed matrix
c_word_embed = 52
c_vocab_size = len(c_word_set)+1 # consider masking
c_word_embed_matrix = tf.Variable(tf.random_uniform(shape=[c_vocab_size, c_word_embed], minval=-1, maxval=1, seed= seed))
# ---
q_word_embed = 52
q_vocab_size = len(q_word_set)+1 # consider masking
q_word_embed_matrix = tf.Variable(tf.random_uniform(shape=[q_vocab_size, q_word_embed], minval=-1, maxval=1, seed=seed))

# %%
# input, output
c = tf.placeholder(dtype=tf.int32, shape=[batch_size, c_max_len, s_max_len])
c_real_len = tf.placeholder(dtype=tf.int32, shape=[batch_size, c_max_len])
s = tf.placeholder(dtype=tf.int32, shape=[batch_size, s_max_len]) 
q = tf.placeholder(dtype=tf.int32, shape=[batch_size, q_max_len])
q_real_len = tf.placeholder(dtype=tf.int32, shape=[batch_size])
l = tf.placeholder(dtype=tf.float32, shape=[batch_size, c_max_len, c_max_len])
a = tf.placeholder(dtype=tf.float32, shape=[batch_size, len(cqa_word_set)])

# %%
def contextLSTM(c, l, c_real_len, reuse=True, scope= "contextLSTM"):
    
    def sentenceLSTM(s, s_real_len, s_hidden=s_hidden, s_max_len= s_max_len, reuse=reuse, scope= "sentenceLSTM"):
        """
        embedding sentence

        Arguments
            s: sentence (word index list), shape = [batch_size, 12]
            s_real_len: length of the sentence before zero padding, int32

        Returns
            embedded_s: embedded sentence, shape = [batch_size, 32]
        """
        embedded_sent_word = tf.nn.embedding_lookup(c_word_embed_matrix, s)
        s_input = tf.unstack(embedded_sent_word, num=s_max_len, axis=1)
        lstm_cell = rnn.BasicLSTMCell(s_hidden, reuse=reuse)
        outputs, _ = rnn.static_rnn(lstm_cell, s_input, dtype=tf.float32, scope= scope)
        # 'outputs' is a list of output at every timestep, we pack them in a Tensor
        outputs = tf.stack(outputs)
        # and change back dimension to [batch_size(64), s_max_len(12), s_hidden(32)]
        outputs = tf.transpose(outputs, [1, 0, 2])
        # Start indices for each sample
        index = tf.range(0, batch_size) * (s_max_len) + (s_real_len-1)
        # Indexing
        outputs = tf.gather(tf.reshape(outputs, [-1, s_hidden]), index)
        return outputs
    
    """
    Args
        c: list of sentences, shape = [batch_size, 20, 12]
        l: list of labels, shape = [batch_size, 20, 20]
        c_real_len: list of real length, shape = [batch_size, 20]
        
    Returns
        tagged_c_objects: list of embedded sentence + label, shape = [batch_size, 52] 20개
        len(tagged_c_objects) = 20
    """
    context = tf.unstack(c, axis=1) 
    real_lens = tf.unstack(c_real_len, axis=1)
    labels = tf.unstack(l, axis=1)
    tagged_c_objects = []
    for sentence, real_len, label in zip(context, real_lens, labels):
        s_embedded = sentenceLSTM(sentence, real_len, reuse=reuse)
        c_embedded = tf.concat([s_embedded, label], axis= 1)
        tagged_c_objects.append(c_embedded)
                                 
    return tagged_c_objects

# %%
def questionLSTM(q, q_real_len, q_hidden=q_hidden, reuse=True, scope = "questionLSTM"):
    """
    Args
        q: zero padded qeustions, shape=[batch_size, q_max_len]
        q_real_len: original question length, shape = [batch_size, 1]
        
    Returns
        embedded_q: embedded questions, shape = [batch_size, q_hidden(32)]
    """
    embedded_q_word = tf.nn.embedding_lookup(q_word_embed_matrix, q)
    q_input = tf.unstack(embedded_q_word, num=q_max_len, axis=1)
    lstm_cell = rnn.BasicLSTMCell(q_hidden, reuse=reuse)
    outputs, _ = rnn.static_rnn(lstm_cell, q_input, dtype=tf.float32, scope = scope)
    # 'outputs' is a list of output at every timestep, we pack them in a Tensor
    outputs = tf.stack(outputs)
    # and change back dimension to [batch_size(64), q_max_len(12), s_hidden(32)]
    outputs = tf.transpose(outputs, [1, 0, 2])
    # Start indices for each sample
    index = tf.range(0, batch_size) * (q_max_len) + (q_real_len-1)
    # Indexing
    outputs = tf.gather(tf.reshape(outputs, [-1, s_hidden]), index)
    return outputs

# %%
def convert_to_RN_input(embedded_c, embedded_q):
    """
    
    Args
        embedded_c: output of contextLSTM, 20 length list of embedded sentences
        embedded_q: output of questionLSTM, embedded question
        
    Returns
        RN_input: input for RN g_theta, shape = [batch_size*190, (52+52+32)]
        considered batch_size and all combinations
    """
    # 20 combination 2 --> total 190 object pairs
    object_pairs = list(itertools.combinations(embedded_c, 2))
    # concatenate with question
    RN_inputs = []
    for object_pair in object_pairs:
        RN_input = tf.concat([object_pair[0], object_pair[1], embedded_q], axis=1)
        RN_inputs.append(RN_input)
    
    return tf.concat(RN_inputs, axis=0)

# %% [markdown]
# #### RN
# * $g_\theta$: 4 layer, all 256 units MLP, ReLU
# * $f_\phi$: 3 layer, 256/512/159 units MLP, ReLU, sotmax

# %%
g_units = [256,256,256,256]
f_units = [256,512,159]

# %%
def fc(inputs, output_shape, activation_fcn = tf.nn.relu, name="fc"):
    output = slim.fully_connected(inputs, int(output_shape), activation_fn=activation_fcn)
    return output

# %%
def g_theta(RN_input, scope= 'g_theta', reuse= True): 
    """
    Args
        RN_input: [o_i, o_j, q], shape = [batch_size*190, 136]
        
    Returns
        g_output: shape = [190, batch_size, 256]
    """
    input_dim = RN_input.shape[1]
    with tf.variable_scope(scope, reuse= reuse) as scope:
        # if not reuse: log.warn(scope.name): reuse하는지 확인하기 위한 출력옵션
#         if not reuse:
#             print(scope.name)
        g_1 = fc(RN_input, g_units[0], name= "g_1")
        g_2 = fc(g_1, g_units[1], name= "g_2")
        g_3 = fc(g_2, g_units[2], name= "g_3")
        g_4 = fc(g_3, g_units[3], name= "g_4")
    g_output = tf.reshape(g_4, shape=[190, batch_size, g_units[3]])
    return g_output

# %%
def f_phi(g, scope= 'f_phi', reuse=True):
    """
    Args
        g: g_theta result, shape = [190, batch_size, 256]
        
    Returns
        f_output: shape = [batch_size, 159]
    """
    f_input = tf.reduce_sum(g, axis=0)
    with tf.variable_scope(scope, reuse=reuse) as scope:
        f_1 = fc(f_input, f_units[0], name= "f_1")
        f_2 = fc(f_1, f_units[1], name= "f_2")
        f_3 = fc(f_2, f_units[2], activation_fcn= None, name= "f_3")
    return f_3

# %% [markdown]
# reuse...

# %%
def model(c, q, l, c_real_len, q_real_len):
    embedded_c = contextLSTM(c, l, c_real_len, reuse=True)
    embedded_q = questionLSTM(q, q_real_len, reuse=None)
    RN_input = convert_to_RN_input(embedded_c, embedded_q)
    f_input = g_theta(RN_input, reuse=None)
    prediction = f_phi(f_input, reuse=None)
    return prediction

# %%
prediction = model(c,q,l,c_real_len, q_real_len)
# Out:
# g_theta

# %%
tf.trainable_variables()
# Out:
# [<tf.Variable 'Variable:0' shape=(125, 52) dtype=float32_ref>,
#  <tf.Variable 'Variable_1:0' shape=(89, 52) dtype=float32_ref>,
#  <tf.Variable 'sentenceLSTM/basic_lstm_cell/weights:0' shape=(84, 128) dtype=float32_ref>,
#  <tf.Variable 'sentenceLSTM/basic_lstm_cell/biases:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'questionLSTM/basic_lstm_cell/weights:0' shape=(84, 128) dtype=float32_ref>,
#  <tf.Variable 'questionLSTM/basic_lstm_cell/biases:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'g_theta/fully_connected/weights:0' shape=(136, 256) dtype=float32_ref>,
#  <tf.Variable 'g_theta/fully_connected/biases:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'g_theta/fully_connected_1/weights:0' shape=(256, 256) dtype=float32_ref>,
#  <tf.Variable 'g_theta/fully_connected_1/biases:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'g_theta/fully_connected_2/weights:0' shape=(256, 256) dtype=float32_ref>,
#  <tf.Variable 'g_theta/fully_connected_2/biases:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'g_theta/fully_connected_3/weights:0' shape=(256, 256) dtype=float32_ref>,
#  <tf.Variable 'g_theta/fully_connected_3/biases:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'f_phi/fully_connected/weights:0' shape=(256, 256) dtype=float32_ref>,
#  <tf.Variable 'f_phi/fully_connected/biases:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'f_phi/fully_connected_1/weights:0' shape=(256, 512) dtype=float32_ref>,
#  <tf.Variable 'f_phi/fully_connected_1/biases:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'f_phi/fully_connected_2/weights:0' shape=(512, 159) dtype=float32_ref>,
#  <tf.Variable 'f_phi/fully_connected_2/biases:0' shape=(159,) dtype=float32_ref>]

# %% [markdown]
# #### Optimization
# * 64 mini batches
# * cross-entropy loss function
# * Adam optimizer
# * learning rate: 2e-4

# %% [markdown]
# ## Issues
# 1. multiple answer?

# %%
correct = tf.equal(tf.argmax(prediction, axis=1), tf.argmax(a, axis=1))
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
loss = tf.nn.softmax_cross_entropy_with_logits(logits=prediction, labels=a)

# %%
global_step = tf.Variable(0, name="global_step", trainable=False)

# %%
opt = tf.train.AdamOptimizer(learning_rate=learning_rate)
optimizer = opt.minimize(loss, global_step=global_step)

# %% [markdown]
# ## Train!

# %%
def batch_iter(c, q, l, a, c_real_len, q_real_len, batch_size=batch_size, num_epochs=iter_time, shuffle=True):
    """
    Generates a batch iterator for a dataset.
    """
    c = np.array(c)
    q = np.array(q)
    l = np.array(l)
    a = np.array(a)
    c_real_len = np.array(c_real_len)
    q_real_len = np.array(q_real_len)
    data_size = len(q)
    num_batches_per_epoch = int(data_size/batch_size) + 1
    for epoch in range(num_epochs):
        print("In epoch >> " + str(epoch + 1))
        print("num batches per epoch is: " + str(num_batches_per_epoch))
        # Shuffle the data at each epoch
        if shuffle:
            shuffle_indices = np.random.permutation(np.arange(data_size))
            c_shuffled = c[shuffle_indices]
            q_shuffled = q[shuffle_indices]
            l_shuffled = l[shuffle_indices]
            a_shuffled = a[shuffle_indices]
            c_real_len_shuffled = c_real_len[shuffle_indices]
            q_real_len_shuffled = q_real_len[shuffle_indices]
        else:
            c_shuffled = c
            q_shuffled = q
            l_shuffled = l
            a_shuffled = a
            c_real_len_shuffled = c_real_len
            q_real_len_shuffled = q_real_len
        
        for batch_num in range(num_batches_per_epoch):
            start_index = batch_num * batch_size
            end_index = (batch_num + 1) * batch_size
            if end_index < data_size:
                c_batch, q_batch, l_batch, a_batch, c_real_len_batch, q_real_len_batch = c_shuffled[start_index:end_index], q_shuffled[start_index:end_index], l_shuffled[start_index:end_index], a_shuffled[start_index:end_index], c_real_len_shuffled[start_index:end_index], q_real_len_shuffled[start_index:end_index]
            yield list(zip(c_batch, q_batch, l_batch, a_batch, c_real_len_batch, q_real_len_batch))

# %%
with tf.Session() as sess:
    init = tf.global_variables_initializer()
    sess.run(init)
    print("====training====")    
    batch_train = batch_iter(train_c, train_q, train_l, train_a, train_c_real_len, train_q_real_len)
    for train in batch_train:
        c_batch, q_batch, l_batch, a_batch, c_real_len_batch, q_real_len_batch = zip(*train)
        current_step = sess.run(global_step, feed_dict={c:c_batch, q:q_batch, l:l_batch, a:a_batch, c_real_len:c_real_len_batch, q_real_len:q_real_len_batch})
        optimizer.run(feed_dict={c:c_batch, q:q_batch, l:l_batch, a:a_batch, c_real_len:c_real_len_batch, q_real_len:q_real_len_batch})
        if current_step % (display_step) == 0:
            print("step: {}".format(current_step))
            print("====validation start====")
            batch_val = batch_iter(val_c, val_q, val_l, val_a, val_c_real_len, val_q_real_len)
            accs = []
            for val in batch_val:
                c_val, q_val, l_val, a_val, c_real_len_val, q_real_len_val = zip(*val)
                acc = accuracy.eval(feed_dict={c:c_val, q:q_val, l:l_val, a:a_val, c_real_len:c_real_len_val, q_real_len:q_real_len_val})
                accs.append(acc)
            print("Mean accuracy=" + str(sum(accs)/len(accs)))
            print("====training====")
# Out:
# In epoch >> 1
# num batches per epoch is: 2812
# step: 0
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=5.00801282051e-05
# ====training====
# step: 100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.192282652244
# ====training====
# step: 200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0356904380342
# ====training====
# step: 300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0436364850427
# ====training====
# step: 400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0756961137821
# ====training====
# step: 500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0456229967949
# ====training====
# step: 600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0508814102564
# ====training====
# step: 700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.143997061966
# ====training====
# step: 800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0390374599359
# ====training====
# step: 900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.118339342949
# ====training====
# step: 1000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.1298828125
# ====training====
# step: 1100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0806456997863
# ====training====
# step: 1200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.123530982906
# ====training====
# step: 1300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.145532852564
# ====training====
# step: 1400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0198150373932
# ====training====
# step: 1500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0811882345085
# ====training====
# step: 1600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.148470886752
# ====training====
# step: 1700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.118472889957
# ====training====
# step: 1800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0794771634615
# ====training====
# step: 1900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0617237580128
# ====training====
# step: 2000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.144222422543
# ====training====
# step: 2100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.102380475427
# ====training====
# step: 2200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.134481837607
# ====training====
# step: 2300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0806039663462
# ====training====
# step: 2400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.14359642094
# ====training====
# step: 2500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0746694711538
# ====training====
# step: 2600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.147177150107
# ====training====
# step: 2700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0349809695513
# ====training====
# step: 2800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0274772970085
# ====training====
# In epoch >> 2
# num batches per epoch is: 2812
# step: 2900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0398637820513
# ====training====
# step: 3000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0303735977564
# ====training====
# step: 3100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.101120125534
# ====training====
# step: 3200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0499215411325
# ====training====
# step: 3300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0637520032051
# ====training====
# step: 3400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0685596955128
# ====training====
# step: 3500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0306406917735
# ====training====
# step: 3600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.136668669872
# ====training====
# step: 3700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0808710603632
# ====training====
# step: 3800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0248147035256
# ====training====
# step: 3900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0828826121795
# ====training====
# step: 4000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.124006744124
# ====training====
# step: 4100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.142060630342
# ====training====
# step: 4200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0854617387821
# ====training====
# step: 4300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.15582431891
# ====training====
# step: 4400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0793018830128
# ====training====
# step: 4500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.126761151175
# ====training====
# step: 4600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0524338942308
# ====training====
# step: 4700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0798193776709
# ====training====
# step: 4800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0418169070513
# ====training====
# step: 4900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0556891025641
# ====training====
# step: 5000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0668653178419
# ====training====
# step: 5100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0595369257479
# ====training====
# step: 5200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.136376535791
# ====training====
# step: 5300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0158503605769
# ====training====
# step: 5400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0945930154915
# ====training====
# step: 5500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0801198584402
# ====training====
# step: 5600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0318926949786
# ====training====
# In epoch >> 3
# num batches per epoch is: 2812
# step: 5700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0237546741453
# ====training====
# step: 5800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0661308092949
# ====training====
# step: 5900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.133939302885
# ====training====
# step: 6000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0794020432692
# ====training====
# step: 6100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0279447115385
# ====training====
# step: 6200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.128004807692
# ====training====
# step: 6300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0622412526709
# ====training====
# step: 6400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.139923878205
# ====training====
# step: 6500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0168102297009
# ====training====
# step: 6600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.13969017094
# ====training====
# step: 6700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0837590144231
# ====training====
# step: 6800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0721905048077
# ====training====
# step: 6900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0394547943376
# ====training====
# step: 7000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0262503338675
# ====training====
# step: 7100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0335453392094
# ====training====
# step: 7200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0399806356838
# ====training====
# step: 7300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0349392361111
# ====training====
# step: 7400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0252320379274
# ====training====
# step: 7500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.031984508547
# ====training====
# step: 7600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.128772702991
# ====training====
# step: 7700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.143888555021
# ====training====
# step: 7800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0663561698718
# ====training====
# step: 7900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0667901976496
# ====training====
# step: 8000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0205495459402
# ====training====
# step: 8100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0340878739316
# ====training====
# step: 8200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.027335403312
# ====training====
# step: 8300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.160456730769
# ====training====
# step: 8400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0340962206197
# ====training====
# In epoch >> 4
# num batches per epoch is: 2812
# step: 8500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0723157051282
# ====training====
# step: 8600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.12797142094
# ====training====
# step: 8700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0692357772436
# ====training====
# step: 8800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0376101762821
# ====training====
# step: 8900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0227697649573
# ====training====
# step: 9000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0716145833333
# ====training====
# step: 9100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0618406116453
# ====training====
# step: 9200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.128856169872
# ====training====
# step: 9300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0779079861111
# ====training====
# step: 9400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.126076722756
# ====training====
# step: 9500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0677250267094
# ====training====
# step: 9600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.126368856838
# ====training====
# step: 9700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0720819978632
# ====training====
# step: 9800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.120576255342
# ====training====
# step: 9900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.021976829594
# ====training====
# step: 10000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.126577524038
# ====training====
# step: 10100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0317758413462
# ====training====
# step: 10200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0285373263889
# ====training====
# step: 10300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0813384748932
# ====training====
# step: 10400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.034430088141
# ====training====
# step: 10500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0934161324786
# ====training====
# step: 10600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0749282184829
# ====training====
# step: 10700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.124240451389
# ====training====
# step: 10800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0372429220085
# ====training====
# step: 10900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0714559962607
# ====training====
# step: 11000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.147093683226
# ====training====
# step: 11100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0592865251068
# ====training====
# step: 11200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0750534188034
# ====training====
# In epoch >> 5
# num batches per epoch is: 2812
# step: 11300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0294137286325
# ====training====
# step: 11400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.143746661325
# ====training====
# step: 11500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0344634748932
# ====training====
# step: 11600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0686765491453
# ====training====
# step: 11700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0337623530983
# ====training====
# step: 11800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0750367254274
# ====training====
# step: 11900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0163094284188
# ====training====
# step: 12000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0592280982906
# ====training====
# step: 12100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.148788060897
# ====training====
# step: 12200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 12300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 12400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 12500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 12600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 12700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 12800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 12900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 13000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 13100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 13200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 13300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 13400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 13500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 13600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 13700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 13800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 13900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 14000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# In epoch >> 6
# num batches per epoch is: 2812
# step: 14100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 14200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 14300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 14400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 14500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 14600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 14700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 14800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 14900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 15000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 15100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 15200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 15300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 15400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 15500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 15600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 15700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 15800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 15900
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 16000
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 16100
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 16200
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 16300
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 16400
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 16500
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 16600
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 16700
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
# step: 16800
# ====validation start====
# In epoch >> 1
# num batches per epoch is: 312
# In epoch >> 2
# num batches per epoch is: 312
# In epoch >> 3
# num batches per epoch is: 312
# In epoch >> 4
# num batches per epoch is: 312
# In epoch >> 5
# num batches per epoch is: 312
# In epoch >> 6
# num batches per epoch is: 312
# Mean accuracy=0.0
# ====training====
